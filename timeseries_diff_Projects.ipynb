# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiataoufik/Census_income-/blob/master/timeseries_diff_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#time setries with pandas 
from datetime import datetime

# %%
my_year=2020
my_month=1
my_day=2
my_hour=13
my_min=30
my_sec=15
my_date=datetime(my_year,my_month,my_day)
my_date
# Out:
# datetime.datetime(2020, 1, 2, 0, 0)

# %%
my_date.hour
# Out:
# 0

# %%
import numpy as np

# %%
np.array(['2020-03-15','2020-03-16','2020-03-17'],dtype="datetime64[h]")
# Out:
# array(['2020-03-15T00', '2020-03-16T00', '2020-03-17T00'],
#       dtype='datetime64[h]')

# %%
np.arange('2018-06-01','2018-06-23',7,dtype="datetime64[D]")
# Out:
# array(['2018-06-01', '2018-06-08', '2018-06-15', '2018-06-22'],
#       dtype='datetime64[D]')

# %%
import pandas as pd

# %%
pd.date_range('2020-01-01',periods=7,freq="D")
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('Jan 01, 2018',periods=7,freq="D")
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.to_datetime(['2/1/2018','3/1/2018'],format="%d/%m/%Y")
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
import numpy as np
data=np.random.randn(3,2)
data
# Out:
# array([[ 0.52565091, -0.23595287],
#        [ 0.40894085, -1.63118346],
#        [ 0.58159646, -0.96667215]])

# %%
idx=pd.date_range('2020-01-01',periods=3,freq="D")

# %%
cols=['A','B']
df=pd.DataFrame(data,index=idx,columns=cols)

# %%
df
# Out:
#                    A         B
# 2020-01-01  0.525651 -0.235953
# 2020-01-02  0.408941 -1.631183
# 2020-01-03  0.581596 -0.966672

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03'], dtype='datetime64[ns]', freq='D')

# %%
df.index.max()
# Out:
# Timestamp('2020-01-03 00:00:00', freq='D')

# %%
df.index.argmax()
# Out:
# 2

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/starbucks.csv",index_col="Date",parse_dates=True)
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2015-01-02 to 2018-12-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1006 non-null   float64
#  1   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 23.6 KB

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.resample(rule="A").mean()
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
def first_date(entry):
  if len(entry)!=0:
    return entry[0]

# %%
df.resample(rule="A").apply(first_date)
# Out:
#               Close    Volume
# Date
# 2015-12-31  38.0061   6906098
# 2016-12-31  55.0780  13521544
# 2017-12-31  53.1100   7809307
# 2018-12-31  56.3243   7215978

# %%
df['Close'].resample('A').mean().plot.bar()

# %%
#time shiffting 
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
df.shift(1).tail()
# Out:
#             Close      Volume
# Date
# 2018-12-24  61.39  23524888.0
# 2018-12-26  60.56   6323252.0
# 2018-12-27  63.08  16646238.0
# 2018-12-28  63.20  11308081.0
# 2018-12-31  63.39   7712127.0

# %%
import pandas as pd

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df['Close'].plot(figsize=(12,5))

# %%
df['Close'].plot()
df.rolling(window=15).mean()['Close'].plot()

# %%
df['Close:30 days mean']=df['Close'].rolling(window=30).mean()
df.head()
# Out:
#               Close    Volume  Close:30 days mean
# Date
# 2015-01-02  38.0061   6906098                 NaN
# 2015-01-05  37.2781  11623796                 NaN
# 2015-01-06  36.9748   7664340                 NaN
# 2015-01-07  37.8848   9732554                 NaN
# 2015-01-08  38.4961  13170548                 NaN

# %%
df[['Close','Close:30 days mean']].plot()

# %%
df['Close'].expanding().mean().plot()

# %%
#visualize time series 
df=pd.read_csv("/content/drive/MyDrive/starbucks.csv",index_col="Date",parse_dates=True)
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.index=pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.plot()

# %%
df['Close'].plot()

# %%
df['Volume'].plot()

# %%
title="title"
xlabel='xlabel'
ylabel='ylabel'
ax=df['Close'].plot(title=title)
ax.autoscale(axis='both',tight=True)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'ylabel'), Text(0.5, 0, 'xlabel')]

# %%
df['Close']['2017-01-01':'2017-12-31'].plot(figsize=(12,4))

# %%
df['Close'].plot(figsize=(12,4),xlim=['2017-01-01','2017-12-31'])

# %%
from matplotlib import dates

# %%
dates.WeekdayLocator

# %%
ax=df['Close'].plot(figsize=(12,4),xlim=['2017-01-01','2017-03-01'],ylim=[50,60])
ax.set(xlabel=" ")
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter("%a-%B-%d"))
ax.xaxis.set_minor_formatter(dates.DateFormatter('\n\n\n%b'))
ax.xaxis.set_minor_locator(dates.MonthLocator())

# %%
#4/1AX4XfWjERyGtRP2Ry91GvzjAS8SC9jFILR2MGB6gWnnQxY_AfMbXfgNjWiw

# %%
#time series with stats model 
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/macrodata.csv",index_col=0,parse_dates=True)

# %%
df.head()
# Out:
#             year  quarter   realgdp  realcons  ...  unemp      pop  infl  realint
# 1959-03-31  1959        1  2710.349    1707.4  ...    5.8  177.146  0.00     0.00
# 1959-06-30  1959        2  2778.801    1733.7  ...    5.1  177.830  2.34     0.74
# 1959-09-30  1959        3  2775.488    1751.8  ...    5.3  178.657  2.74     1.09
# 1959-12-31  1959        4  2785.204    1753.7  ...    5.6  179.386  0.27     4.06
# 1960-03-31  1960        1  2847.699    1770.5  ...    5.2  180.007  2.31     1.19
#
# [5 rows x 14 columns]

# %%
df.index
# Out:
# DatetimeIndex(['1959-03-31', '1959-06-30', '1959-09-30', '1959-12-31',
#                '1960-03-31', '1960-06-30', '1960-09-30', '1960-12-31',
#                '1961-03-31', '1961-06-30',
#                ...
#                '2007-06-30', '2007-09-30', '2007-12-31', '2008-03-31',
#                '2008-06-30', '2008-09-30', '2008-12-31', '2009-03-31',
#                '2009-06-30', '2009-09-30'],
#               dtype='datetime64[ns]', length=203, freq=None)

# %%
#use stats modes
df['realgdp'].plot(figsize=(12,5))

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
gdp_cycle,gdp_trend=hpfilter(df['realgdp'])

# %%
df['trend']=gdp_trend

# %%
df[['trend','realgdp']]['2005-01-01':].plot(figsize=(12,4))

# %%
gdp_cycle.plot()

# %%
#ETS Decomposition 
airline=pd.read_csv("/content/drive/MyDrive/airline_passengers.csv",index_col=0,parse_dates=True)
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
airline.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
airline.isnull().sum()
# Out:
# Thousands of Passengers    0
# dtype: int64

# %%
airline=airline.dropna()

# %%
airline.plot(figsize=(12,4))

# %%
#multi model
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result=seasonal_decompose(airline['Thousands of Passengers'],model='multiplicative')

# %%
result.seasonal
# Out:
# Month
# 1949-01-01    0.910230
# 1949-02-01    0.883625
# 1949-03-01    1.007366
# 1949-04-01    0.975906
# 1949-05-01    0.981378
#                 ...
# 1960-08-01    1.219911
# 1960-09-01    1.060492
# 1960-10-01    0.921757
# 1960-11-01    0.801178
# 1960-12-01    0.898824
# Name: Thousands of Passengers, Length: 144, dtype: float64

# %%
from pylab import rcParams
rcParams['figure.figsize']=12,4
result.plot()

# %%
#ewma 
airline['6-month_SMA']=airline['Thousands of Passengers'].rolling(window=6).mean()

# %%
airline['12-month_SMA']=airline['Thousands of Passengers'].rolling(window=12).mean()

# %%
airline.plot(figsize=(12,4))

# %%
airline['EMA-12']=airline['Thousands of Passengers'].ewm(span=12).mean()

# %%
airline[['Thousands of Passengers','EMA-12']].plot()

# %%
#holt winter methodes 
df=pd.read_csv("/content/drive/MyDrive/airline_passengers.csv",index_col=0,parse_dates=True)
df.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df=df.dropna()

# %%
df.index.freq='MS'

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
span=12
alpha=2/(span+1)

# %%
df['EWMA']=df['Thousands of Passengers'].ewm(alpha=alpha,adjust=False).mean()

# %%
df.head()
# Out:
#             Thousands of Passengers        EWMA
# Month
# 1949-01-01                      112  112.000000
# 1949-02-01                      118  112.923077
# 1949-03-01                      132  115.857988
# 1949-04-01                      129  117.879836
# 1949-05-01                      121  118.359861

# %%
model=SimpleExpSmoothing(df['Thousands of Passengers'])

# %%
fitted_model=model.fit(smoothing_level=alpha,optimized=False)

# %%
df['SES12']=fitted_model.fittedvalues.shift(-1)

# %%
df.head()
# Out:
#             Thousands of Passengers        EWMA       SES12
# Month
# 1949-01-01                      112  112.000000  112.000000
# 1949-02-01                      118  112.923077  112.923077
# 1949-03-01                      132  115.857988  115.857988
# 1949-04-01                      129  117.879836  117.879836
# 1949-05-01                      121  118.359861  118.359861

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
df['DES_ADD_12']=ExponentialSmoothing(df['Thousands of Passengers'],trend="additive").fit().fittedvalues.shift(-1)

# %%
df.head()
# Out:
#             Thousands of Passengers        EWMA       SES12  DES_ADD_12
# Month
# 1949-01-01                      112  112.000000  112.000000  114.336233
# 1949-02-01                      118  112.923077  112.923077  120.336233
# 1949-03-01                      132  115.857988  115.857988  134.336233
# 1949-04-01                      129  117.879836  117.879836  131.336233
# 1949-05-01                      121  118.359861  118.359861  123.336233

# %%
df.columns
# Out:
# Index(['Thousands of Passengers', 'EWMA', 'SES12', 'DES_ADD_12'], dtype='object')

# %%
df[['Thousands of Passengers',  'SES12', 'DES_ADD_12']].iloc[:24].plot()

# %%
#triple expential smoothing 
df['TES_mul_12']=ExponentialSmoothing(df['Thousands of Passengers'],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues

# %%
df.head()
# Out:
#             Thousands of Passengers        EWMA  ...  DES_ADD_12  TES_mul_12
# Month                                            ...
# 1949-01-01                      112  112.000000  ...  114.336233  111.583236
# 1949-02-01                      118  112.923077  ...  120.336233  118.839294
# 1949-03-01                      132  115.857988  ...  134.336233  133.327416
# 1949-04-01                      129  117.879836  ...  131.336233  127.915388
# 1949-05-01                      121  118.359861  ...  123.336233  120.978320
#
# [5 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Thousands of Passengers', 'EWMA', 'SES12', 'DES_ADD_12', 'TES_mul_12'], dtype='object')

# %%
df[['Thousands of Passengers', 'DES_ADD_12', 'TES_mul_12']].iloc[:24].plot(figsize=(12,6))

# %%
## General forecasting:

#intro forcasting 
#acf -pacf plot
#autoregression-AR
#Descriptive statistics and test
#choosing arima orders
#arima based models
#holter can model an existing time series ,let s see how we can use that model on future dates forecasting for dates that have not  happened yet 
#how evaluate the forecasting prediction

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/airline_passengers.csv",index_col=0,parse_dates=True)
df.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df.index.freq='MS'

# %%
df.tail()
# Out:
#             Thousands of Passengers
# Month
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432

# %%
(75*144)/100
# Out:
# 108.0

# %%
#1961 wil be the future
#test train split 
train_data=df.iloc[:109]
test_data=df.iloc[108:]

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
fitted_model=ExponentialSmoothing(train_data['Thousands of Passengers'],trend="mul",seasonal="mul",seasonal_periods=12).fit()

# %%
test_predictions=fitted_model.forecast(36)

# %%
test_predictions
# Out:
# 1958-02-01    339.140408
# 1958-03-01    399.277401
# 1958-04-01    394.227360
# 1958-05-01    402.541372
# 1958-06-01    473.133165
# 1958-07-01    521.801193
# 1958-08-01    514.525372
# 1958-09-01    446.222776
# 1958-10-01    385.432121
# 1958-11-01    339.645926
# 1958-12-01    381.452236
# 1959-01-01    401.211186
# 1959-02-01    387.157129
# 1959-03-01    455.808535
# 1959-04-01    450.043490
# 1959-05-01    459.534631
# 1959-06-01    540.121064
# 1959-07-01    595.679687
# 1959-08-01    587.373728
# 1959-09-01    509.400604
# 1959-10-01    440.002990
# 1959-11-01    387.734221
# 1959-12-01    435.459618
# 1960-01-01    458.016112
# 1960-02-01    441.972230
# 1960-03-01    520.343550
# 1960-04-01    513.762270
# 1960-05-01    524.597200
# 1960-06-01    616.593351
# 1960-07-01    680.018164
# 1960-08-01    670.536218
# 1960-09-01    581.523378
# 1960-10-01    502.300199
# 1960-11-01    442.631029
# 1960-12-01    497.113561
# 1961-01-01    522.863684
# Freq: MS, dtype: float64

# %%
train_data['Thousands of Passengers'].plot(legend=True,label='Train',figsize=(12,8))
test_data['Thousands of Passengers'].plot(legend=True,label="test",figsize=(12,8))

# %%
train_data['Thousands of Passengers'].plot(legend=True,label='Train',figsize=(12,8))
test_data['Thousands of Passengers'].plot(legend=True,label="test",figsize=(12,8))
test_predictions.plot(legend=True,label='Predictions',xlim=['1958-01-01','1961-01-01'])

# %%
#evalution matrix 
#mean absulte error
#mean squared error
#root mean sqaure error(y true , yhat : predicted value)
#1.mean absolute error :1/n(sum(absulute(y-yhat)))
#2.mean squared erro :1/n(sum((y-yhat))^2
#3.root mean square error root(1/n(sum((y-yhat))^2)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(test_data,test_predictions)
# Out:
# 63.03138491847624

# %%
mean_squared_error(test_data,test_predictions)
# Out:
# 5614.4207149269

# %%
test_data.describe()
# Out:
#        Thousands of Passengers
# count                36.000000
# mean                428.500000
# std                  79.329152
# min                 310.000000
# 25%                 362.000000
# 50%                 412.000000
# 75%                 472.000000
# max                 622.000000

# %%
np.sqrt(mean_squared_error(test_data,test_predictions))
# Out:
# 74.92943823976594

# %%
#forecast into the future
final_model=ExponentialSmoothing(df['Thousands of Passengers'],trend='mul',seasonal='mul',seasonal_periods=12).fit()

# %%
forcast_prediction=final_model.forecast(36)

# %%
df['Thousands of Passengers'].plot(figsize=(12,4))
forcast_prediction.plot(figsize=(12,4))

# %%
df2=pd.read_csv("/content/drive/MyDrive/samples.csv",index_col=0,parse_dates=True)
df2.head()
# Out:
#              a   b  c   d
# 1950-01-01  36  27  0  67
# 1950-02-01  58  22  3  31
# 1950-03-01  61  17  5  67
# 1950-04-01  37  15  8  47
# 1950-05-01  66  13  8  62

# %%
df2['a'].plot()

# %%
df2['b'].plot()

# %%
#stationary :does not exibit trend(growing or decreasing on avreafe ) or seasinality(repeat over time)
#non stationarity (has trend or seasonal ) df2[b]

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
#non stationary (growing trend)
#df2['b']-df2['b'].shift(1)
diff(df2['b'],k_diff=1).plot()

# %%
#ACF AND PACF 
#ACF:AUtocorelation function plot
#correlation :measure of the strength of the linear relationship between two variables 
#autocorrelation :correlation of the series with itself lagged by x time units

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import acf,acovf,pacf,pacf_yw,pacf_ols

# %%
#non stationary 
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
#stationary 
df2=pd.read_csv("/content/drive/MyDrive/DailyTotalFemaleBirths.csv",index_col=0,parse_dates=True)
df2.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
df2.index.freq='D'

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df1=pd.DataFrame({'a':[13,5,11,12,9]})

# %%
df1
# Out:
#     a
# 0  13
# 1   5
# 2  11
# 3  12
# 4   9

# %%
acf(df1['a'])
# Out:
# array([ 1.   , -0.5  , -0.2  ,  0.275, -0.075])

# %%
pacf_yw(df1['a'],nlags=4,method='mle')
# Out:
# array([ 1.        , -0.5       , -0.6       , -0.38541667, -0.40563273])

# %%
pacf_ols(df1['a'],nlags=4)
# Out:
# array([ 1.        , -0.49677419, -0.43181818,  0.53082621,  0.25434783])

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df['Thousands of Passengers'])

# %%
lag_plot(df2['Births'])

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(df,lags=40);

# %%
plot_acf(df2,lags=40);

# %%
plot_pacf(df,lags=40);

# %%
plot_pacf(df2,lags=40);

# %%
#arima overview :
#time series model (autoregressive moving average )

# %%
#NON Seasonal arima (non stationarity)
#arima(p,d,q)connected to the three element 
#AR(P):regression utilizes the dependent relationship over time
#I(d): integrated (differencing to make time series stationary)
#MA(Moving average(q)): dependancy between observation and risidual error
#STAtionary (CONtante mean and variance over time )
#to test stationarity we can use AUgmaneted dickey fuller test 
#transform non stationary to stattionary using diffrencing method
#PICK pdq(AUTOCORRELATION PLOT ) or using Grid search (run banch of arima model and evaluate diiferent combination )

# %%
#AR:AUTOREGRESSION :forecast using linear combination of past values of the varialbes 
import pandas as pd 
import numpy as np 
from statsmodels.tsa.ar_model import AR,ARResults
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv("/content/drive/MyDrive/uspopulation.csv",index_col=0,parse_dates=True)
df.head()
# Out:
#             PopEst
# DATE
# 2011-01-01  311037
# 2011-02-01  311189
# 2011-03-01  311351
# 2011-04-01  311522
# 2011-05-01  311699

# %%
df.index.freq='MS'

# %%
df.plot(figsize=(12,4))

# %%
len(df)
# Out:
# 96

# %%
train=df.iloc[:84]
test=df.iloc[84:]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model=AR(train['PopEst'])

# %%
AR1fit=model.fit(maxlag=1)

# %%
AR1fit.k_ar
# Out:
# 1

# %%
AR1fit.params
# Out:
# const        284.913797
# L1.PopEst      0.999686
# dtype: float64

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
AR1fit.predict(start=start,end=end)
# Out:
# 2018-01-01    326560.403377
# 2018-02-01    326742.749463
# 2018-03-01    326925.038278
# 2018-04-01    327107.269838
# 2018-05-01    327289.444162
# 2018-06-01    327471.561268
# 2018-07-01    327653.621173
# 2018-08-01    327835.623896
# 2018-09-01    328017.569455
# 2018-10-01    328199.457868
# 2018-11-01    328381.289152
# 2018-12-01    328563.063326
# Freq: MS, dtype: float64

# %%
test
# Out:
#             PopEst
# DATE
# 2018-01-01  326527
# 2018-02-01  326669
# 2018-03-01  326812
# 2018-04-01  326968
# 2018-05-01  327134
# 2018-06-01  327312
# 2018-07-01  327502
# 2018-08-01  327698
# 2018-09-01  327893
# 2018-10-01  328077
# 2018-11-01  328241
# 2018-12-01  328393

# %%
predictions1=AR1fit.predict(start=start,end=end)
predictions1
# Out:
# 2018-01-01    326560.403377
# 2018-02-01    326742.749463
# 2018-03-01    326925.038278
# 2018-04-01    327107.269838
# 2018-05-01    327289.444162
# 2018-06-01    327471.561268
# 2018-07-01    327653.621173
# 2018-08-01    327835.623896
# 2018-09-01    328017.569455
# 2018-10-01    328199.457868
# 2018-11-01    328381.289152
# 2018-12-01    328563.063326
# Freq: MS, dtype: float64

# %%
predictions1=predictions1.rename('AR(1) Predictions')

# %%
test.plot(figsize=(12,5),legend=True)
predictions1.plot(figsize=(12,5),legend=True)

# %%
AR2fit=model.fit(maxlag=2)

# %%
predictions2=AR2fit.predict(start,end)

# %%
predictions2=predictions2.rename("AR2 predictions")

# %%
test.plot(figsize=(12,5),legend=True)
predictions1.plot(figsize=(12,5),legend=True)
predictions2.plot(figsize=(12,5),legend=True)

# %%
#let statsmodels choose the p order 
ARfit=model.fit(ic='t-stat')

# %%
predictions8=ARfit.predict(start,end)
predictions8=predictions8.rename('AR8 prediction')

# %%
ARfit.params
# Out:
# const        82.309677
# L1.PopEst     2.437997
# L2.PopEst    -2.302100
# L3.PopEst     1.565427
# L4.PopEst    -1.431211
# L5.PopEst     1.125022
# L6.PopEst    -0.919494
# L7.PopEst     0.963694
# L8.PopEst    -0.439511
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
labels=['AR1','AR2','AR8']

# %%
preds=[predictions1,predictions2,predictions8]

# %%
for i in range(3):
  error=mean_squared_error(test['PopEst'],preds[i])
  print(f'{labels[i]} MSE ERRO WAS: {error}')
# Out:
# AR1 MSE ERRO WAS: 17449.714242014332
# AR2 MSE ERRO WAS: 2713.258895540958
# AR8 MSE ERRO WAS: 186.97809636815634

# %%
test.plot(figsize=(12,5),legend=True)
predictions1.plot(figsize=(12,5),legend=True)
predictions2.plot(figsize=(12,5),legend=True)
predictions8.plot(figsize=(12,5),legend=True)

# %%
#forcast for the future
model=AR(df['PopEst'])

# %%
ARfit=model.fit(ic='t-stat')

# %%
forcastd_model=ARfit.predict(start=len(df),end=len(df)+12)

# %%
forcastd_model=forcastd_model.rename('forcast')

# %%
df.plot(figsize=(12,4),legend=True)
forcastd_model.plot(figsize=(12,4),legend=True)

# %%
#descriptive statistics and test 
#test for stationary using Dickey fuller test 
#granger causality test 
#AIC AKAIKE information Criterion : evaluate collection of models 
#BIC

# %%
import pandas as pd 
import numpy as np

# %%
df1=pd.read_csv('/content/drive/MyDrive/airline_passengers.csv',index_col=0,parse_dates=True)
df2=pd.read_csv('/content/drive/MyDrive/DailyTotalFemaleBirths.csv',index_col=0,parse_dates=True)

# %%
df1.index.freq='MS'

# %%
df2.index.freq='D'

# %%
df1.plot()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df1['Thousands of Passengers'])
# Out:
# (0.8153688792060418,
#  0.9918802434376409,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '10%': -2.578770059171598,
#   '5%': -2.8840418343195267},
#  996.692930839019)

# %%
dftest=adfuller(df1['Thousands of Passengers'])

# %%
dftest[4]
# Out:
# {'1%': -3.4816817173418295,
#  '10%': -2.578770059171598,
#  '5%': -2.8840418343195267}

# %%
dfout=pd.Series(dftest[0:4],index=['adf test statistic','p-value','#lags used','#number of obervations'])

# %%
for key,val in dftest[4].items():
  dfout[f'critical value({key})']=val

# %%
dfout
# Out:
# adf test statistic          0.815369
# p-value                     0.991880
# #lags used                 13.000000
# #number of obervations    130.000000
# critical value(1%)         -3.481682
# critical value(5%)         -2.884042
# critical value(10%)        -2.578770
# dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
df1.plot()

# %%
df2.plot()

# %%
adf_test(df2['Births'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -4.808291
# p-value                   0.000052
# # lags used               6.000000
# # observations          358.000000
# critical value (1%)      -3.448749
# critical value (5%)      -2.869647
# critical value (10%)     -2.571089
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df3=pd.read_csv('/content/drive/MyDrive/samples.csv',index_col=0,parse_dates=True)

# %%
df3.index.freq='MS'

# %%
df3[['a','d']].plot(figsize=(12,4))

# %%
#check the causality 
df3['a'].iloc[2:].plot(figsize=(12,3),legend=True)
df3['d'].shift(2).plot(figsize=(12,3),legend=True)

# %%
#ligning up on top of each others 
from statsmodels.tsa.stattools import grangercausalitytests

# %%
grangercausalitytests(df3[['a','d']],maxlag=3);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7051  , p=0.1942  , df_denom=116, df_num=1
# ssr based chi2 test:   chi2=1.7492  , p=0.1860  , df=1
# likelihood ratio test: chi2=1.7365  , p=0.1876  , df=1
# parameter F test:         F=1.7051  , p=0.1942  , df_denom=116, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=286.0339, p=0.0000  , df_denom=113, df_num=2
# ssr based chi2 test:   chi2=597.3806, p=0.0000  , df=2
# likelihood ratio test: chi2=212.6514, p=0.0000  , df=2
# parameter F test:         F=286.0339, p=0.0000  , df_denom=113, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=188.7446, p=0.0000  , df_denom=110, df_num=3
# ssr based chi2 test:   chi2=602.2669, p=0.0000  , df=3
# likelihood ratio test: chi2=212.4789, p=0.0000  , df=3
# parameter F test:         F=188.7446, p=0.0000  , df_denom=110, df_num=3

# %%
df3.plot()

# %%
grangercausalitytests(df3[['b','d']],maxlag=3);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5225  , p=0.2197  , df_denom=116, df_num=1
# ssr based chi2 test:   chi2=1.5619  , p=0.2114  , df=1
# likelihood ratio test: chi2=1.5517  , p=0.2129  , df=1
# parameter F test:         F=1.5225  , p=0.2197  , df_denom=116, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4350  , p=0.6483  , df_denom=113, df_num=2
# ssr based chi2 test:   chi2=0.9086  , p=0.6349  , df=2
# likelihood ratio test: chi2=0.9051  , p=0.6360  , df=2
# parameter F test:         F=0.4350  , p=0.6483  , df_denom=113, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5333  , p=0.6604  , df_denom=110, df_num=3
# ssr based chi2 test:   chi2=1.7018  , p=0.6365  , df=3
# likelihood ratio test: chi2=1.6895  , p=0.6393  , df=3
# parameter F test:         F=0.5333  , p=0.6604  , df_denom=110, df_num=3

# %%
#evaluate accuracy 
np.random.seed(42)
df=pd.DataFrame(np.random.randint(20,30,(50,2)),columns=['test','predictions'])

# %%
df.head()
# Out:
#    test  predictions
# 0    26           23
# 1    27           24
# 2    26           29
# 3    22           26
# 4    27           24

# %%
df.plot()

# %%
from statsmodels.tools.eval_measures import mse,rmse,meanabs

# %%
mse(df['test'],df['predictions'])
# Out:
# 17.02

# %%
meanabs(df['test'],df['predictions'])
# Out:
# 3.54

# %%
df1.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df1.plot()

# %%
from statsmodels.graphics.tsaplots import month_plot,quarter_plot

# %%
month_plot(df1['Thousands of Passengers']);

# %%
#ARIMA MODEL 
#Non seasonal arima 
#seasonal sarima

# %%
#chooseing ARIMA orders
# p number of lag observations included in the mode 
# d : the number of times that the raw observations are differenced 
# q: the size of the moving avreage window alse called the order of moving average

# %%
df1.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 14.0 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
from pmdarima import auto_arima

# %%
stepwise_fit=auto_arima(df2['Births'],start_p=0,start_q=0,max_p=6,max_q=3,seasonal=False,trace=False)

# %%
stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  365
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -1226.537
# Date:                Thu, 09 Sep 2021   AIC                           2459.074
# Time:                        23:46:24   BIC                           2470.766
# Sample:                             0   HQIC                          2463.721
#                                 - 365
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1252      0.060      2.097      0.036       0.008       0.242
# ma.L1         -0.9624      0.017    -56.429      0.000      -0.996      -0.929
# sigma2        49.1512      3.250     15.122      0.000      42.781      55.522
# ...

# %%
stepwise_fit=auto_arima(df1['Thousands of Passengers'],start_p=0,start_q=0,max_p=4,max_q=4,seasonal=True,trace=True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=1032.128, Time=0.29 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.13 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.23 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.05 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1019.239, Time=0.38 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=2.96 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=1020.493, Time=0.46 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1032.120, Time=0.25 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1021.120, Time=0.53 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=1021.032, Time=0.71 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=1019.178, Time=0.41 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1020.425, Time=0.25 sec
# ...

# %%
stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                  144
# Model:             SARIMAX(0, 1, 1)x(2, 1, [], 12)   Log Likelihood                -505.589
# Date:                             Thu, 09 Sep 2021   AIC                           1019.178
# Time:                                     23:53:51   BIC                           1030.679
# Sample:                                          0   HQIC                          1023.851
#                                              - 144
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3634      0.074     -4.945      0.000      -0.508      -0.219
# ...

# %%
#arima and arma 
from statsmodels.tsa.arima_model import ARIMA,ARMA,ARIMAResults,ARIMAResults

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
df1=pd.read_csv("/content/drive/MyDrive/DailyTotalFemaleBirths.csv",index_col=0,parse_dates=True)
df1.index.freq='D'
df1=df1[:120]

# %%
df2=pd.read_csv("/content/drive/MyDrive/TradeInventories.csv",index_col=0,parse_dates=True)
df2.index.freq='MS'

# %%
#arma (pend q)
df1['Births'].plot(figsize=(12,4))

# %%
adf_test(df1['Births'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -9.855384e+00
# p-value                 4.373545e-17
# # lags used             0.000000e+00
# # observations          1.190000e+02
# critical value (1%)    -3.486535e+00
# critical value (5%)    -2.886151e+00
# critical value (10%)   -2.579896e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
model=auto_arima(df1['Births'],start_p=0,start_q=0,max_p=6,max_q=3,seasonal=False,trace=False)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  120
# Model:                        SARIMAX   Log Likelihood                -409.745
# Date:                Fri, 10 Sep 2021   AIC                            823.489
# Time:                        00:14:14   BIC                            829.064
# Sample:                             0   HQIC                           825.753
#                                 - 120
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     39.7833      0.687     57.896      0.000      38.437      41.130
# sigma2        54.1197      8.319      6.506      0.000      37.815      70.424
# ...
# Ljung-Box (L1) (Q):                   0.85   Jarque-Bera (JB):                 2.69
# ...

# %%
train=df1.iloc[:90]
test=df1.iloc[90:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c9e6eabde31> in <module>()
# ----> 1 train=df1.iloc[:90]
#       2 test=df1.iloc[90:]
#
# NameError: name 'df1' is not defined

# %%
model=ARMA(train['Births'],order=(2,2))

# %%
result=model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                 Births   No. Observations:                   90
# Model:                     ARMA(2, 2)   Log Likelihood                -307.905
# Method:                       css-mle   S.D. of innovations              7.405
# Date:                Fri, 10 Sep 2021   AIC                            627.809
# Time:                        00:15:09   BIC                            642.808
# Sample:                    01-01-1959   HQIC                           633.858
#                          - 03-31-1959
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           39.7549      0.912     43.607      0.000      37.968      41.542
# ar.L1.Births    -0.1850      1.087     -0.170      0.865      -2.315       1.945
# ...

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
predictions=result.predict(start,end).rename("arma(2,2) predictions")

# %%
test['Births'].plot(figsize=(12,4),legend=True)
predictions.plot(figsize=(12,4),legend=True)

# %%
test.mean()
# Out:
# Births    39.833333
# dtype: float64

# %%
predictions.mean()
# Out:
# 39.77743360757545

# %%
#arima 
df2.head()
# Out:
#             Inventories
# Date
# 1997-01-01      1301161
# 1997-02-01      1307080
# 1997-03-01      1303978
# 1997-04-01      1319740
# 1997-05-01      1327294

# %%
df2.plot(figsize=(12,4))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
resul=seasonal_decompose(df2['Inventories'],model='add')

# %%
resul.plot();

# %%
#ignore the seasonal 
auto_arima(df2['Inventories'],seasonal=False).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  264
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -2672.018
# Date:                Fri, 10 Sep 2021   AIC                           5348.037
# Time:                        00:55:16   BIC                           5355.181
# Sample:                             0   HQIC                          5350.908
#                                 - 264
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3258.3802    470.991      6.918      0.000    2335.255    4181.506
# sigma2       3.91e+07   2.95e+06     13.250      0.000    3.33e+07    4.49e+07
# ...
# Ljung-Box (L1) (Q):                  82.61   Jarque-Bera (JB):               100.74
# ...

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
df2['diff']=diff(df2['Inventories'],k_diff=1)

# %%
adf_test(df2['diff'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -3.412249
# p-value                   0.010548
# # lags used               4.000000
# # observations          258.000000
# critical value (1%)      -3.455953
# critical value (5%)      -2.872809
# critical value (10%)     -2.572775
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
plot_acf(df2['Inventories'],lags=40);

# %%
plot_pacf(df2['Inventories'],lags=40);

# %%
#AR=1
#MA=1
#I=0 OR 1 (less error)

# %%
auto_arima(df2['Inventories'],start_p=0,start_q=0,max_p=2,max_q=2,seasonal=False,trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5348.037, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5399.843, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5350.241, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5409.217, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5378.835, Time=0.22 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.371 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  264
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -2672.018
# Date:                Fri, 10 Sep 2021   AIC                           5348.037
# Time:                        00:56:44   BIC                           5355.181
# Sample:                             0   HQIC                          5350.908
# ...

# %%
len(df2)
# Out:
# 264

# %%
train=df2.iloc[:252]
test=df2.iloc[252:]

# %%
model=ARIMA(train['Inventories'],order=(1,1,1))
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:          D.Inventories   No. Observations:                  251
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2486.395
# Method:                       css-mle   S.D. of innovations           4845.028
# Date:                Fri, 10 Sep 2021   AIC                           4980.790
# Time:                        00:59:29   BIC                           4994.892
# Sample:                    02-01-1997   HQIC                          4986.465
#                          - 12-01-2017
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                3197.5697   1344.875      2.378      0.017     561.663    5833.477
# ar.L1.D.Inventories     0.9026      0.039     23.011      0.000       0.826       0.979
# ...

# %%
start=len(train)
end=len(train)+len(test)-1

# %%
predictions=result.predict(start,end,typ='levels')

# %%
test
# Out:
#             Inventories
# Date
# 2018-01-01      2110158
# 2018-02-01      2118199
# 2018-03-01      2112427
# 2018-04-01      2112276
# 2018-05-01      2111835
# 2018-06-01      2109298
# 2018-07-01      2119618
# 2018-08-01      2127170
# 2018-09-01      2134172
# 2018-10-01      2144639
# 2018-11-01      2143001
# 2018-12-01      2158115

# %%
predictions
# Out:
# 2018-01-01    3397.333058
# 2018-02-01    3377.867479
# 2018-03-01    3360.298688
# 2018-04-01    3344.441857
# 2018-05-01    3330.130165
# 2018-06-01    3317.213050
# 2018-07-01    3305.554620
# 2018-08-01    3295.032225
# 2018-09-01    3285.535166
# 2018-10-01    3276.963530
# 2018-11-01    3269.227142
# 2018-12-01    3262.244612
# Freq: MS, dtype: float64

# %%
test['Inventories'].plot(legend=True)
predictions.plot(legend=True)

# %%
from statsmodels.tools.eval_measures import rmse

# %%
rmse(test['Inventories'],predictions)
# Out:
# 7789.596900611291

# %%
test['Inventories'].mean()
# Out:
# 2125075.6666666665

# %%
#forecast into the unkown future 
model=ARIMA(df2['Inventories'],order=(1,1,1))

# %%
result=model.fit()

# %%
fcast=result.predict(start=len(df2),end=len(df2)+11,typ='levels').rename("ARIMA(1,1,1 forcast")

# %%
df2['Inventories'].plot(legend=True)
fcast.plot(legend=True)

# %%
#seasonal arima model (SARIMAX)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 6.4 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 59.5 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
from pmdarima import auto_arima

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/co2_mm_mlo.csv')
df.head()
# Out:
#    year  month  decimal_date  average  interpolated
# 0  1958      3      1958.208   315.71        315.71
# 1  1958      4      1958.292   317.45        317.45
# 2  1958      5      1958.375   317.50        317.50
# 3  1958      6      1958.458      NaN        317.10
# 4  1958      7      1958.542   315.86        315.86

# %%
#dict(year=df['year'],month=df['month'],day=1)

# %%
df['date']=pd.to_datetime({'year':df['year'],'month':df['month'],'day':1})

# %%
df= df.set_index('date')
df.head()
# Out:
#             year  month  decimal_date  average  interpolated
# date
# 1958-03-01  1958      3      1958.208   315.71        315.71
# 1958-04-01  1958      4      1958.292   317.45        317.45
# 1958-05-01  1958      5      1958.375   317.50        317.50
# 1958-06-01  1958      6      1958.458      NaN        317.10
# 1958-07-01  1958      7      1958.542   315.86        315.86

# %%
df.index.freq='MS'

# %%
df['interpolated'].plot(figsize=(12,5))

# %%
result=seasonal_decompose(df['interpolated'],model='add')
result.plot();

# %%
result.seasonal.plot(figsize=(12,4))

# %%
auto_arima(df['interpolated'],seasonal=True,trace=True,m=12).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=463.185, Time=4.69 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2369.532, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=1.24 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1614.808, Time=1.01 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2375.248, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=1101.952, Time=4.31 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=770.617, Time=6.44 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=503.763, Time=12.14 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=538.470, Time=10.97 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=1440.918, Time=0.86 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=11.23 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=611.738, Time=11.36 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=15.11 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=454.611, Time=4.58 sec
# ...

# %%
len(df)
train=df.iloc[:717]
test=df.iloc[717:]

# %%
model=SARIMAX(train['interpolated'],order=(0,1,3),seasonal_order=(1,0,1,12))

# %%
results=model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                         interpolated   No. Observations:                  717
# Model:             SARIMAX(0, 1, 3)x(1, 0, [1], 12)   Log Likelihood                -201.190
# Date:                              Fri, 10 Sep 2021   AIC                            414.380
# Time:                                      19:05:42   BIC                            441.823
# Sample:                                  03-01-1958   HQIC                           424.977
#                                        - 11-01-2017
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3544      0.035    -10.114      0.000      -0.423      -0.286
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
predictions=results.predict(start,end,typ='levels').rename('SARIMA Predictions')

# %%
test['interpolated'].plot(legend=True,figsize=(12,8))
predictions.plot(figsize=(12,4))

# %%
from statsmodels.tools.eval_measures import rmse

# %%
error=rmse(test['interpolated'],predictions)
error
# Out:
# 0.35835582615900824

# %%
test['interpolated'].mean()
# Out:
# 408.3333333333333

# %%
#forecast into the unkown future
model=SARIMAX(df['interpolated'],order=(0,1,3),seasonal_order=(1,0,1,12))

# %%
results=model.fit()

# %%
fcast=results.predict(len(df),len(df)+11,typ='levels').rename('SARIMA FORCAST')

# %%
df['interpolated'].plot(figsize=(12,4),legend=True)
fcast.plot(figsize=(12,4),legend=True)

# %%
#exegenous model
#get dummies ,one hot encoder 
#cooreclation test and see wheteher its a exgenous variable 
import pandas as pd
import numpy as np 

df=pd.read_csv('/content/drive/MyDrive/RestaurantVisitors.csv',index_col=0,parse_dates=True)

# %%
df.index.fre='D'

# %%
df.head()
# Out:
#              weekday  holiday    holiday_name  ...  rest3  rest4  total
# date                                           ...
# 2016-01-01    Friday        1  New Year's Day  ...   67.0  139.0  296.0
# 2016-01-02  Saturday        0              na  ...   43.0   85.0  191.0
# 2016-01-03    Sunday        0              na  ...   66.0   81.0  202.0
# 2016-01-04    Monday        0              na  ...   32.0   32.0  105.0
# 2016-01-05   Tuesday        0              na  ...   38.0   43.0   98.0
#
# [5 rows x 8 columns]

# %%
df.tail()
# Out:
#               weekday  holiday  holiday_name  rest1  rest2  rest3  rest4  total
# date
# 2017-05-27   Saturday        0            na    NaN    NaN    NaN    NaN    NaN
# 2017-05-28     Sunday        0            na    NaN    NaN    NaN    NaN    NaN
# 2017-05-29     Monday        1  Memorial Day    NaN    NaN    NaN    NaN    NaN
# 2017-05-30    Tuesday        0            na    NaN    NaN    NaN    NaN    NaN
# 2017-05-31  Wednesday        0            na    NaN    NaN    NaN    NaN    NaN

# %%
df1=df.dropna()

# %%
df1.tail()
# Out:
#               weekday  holiday holiday_name  rest1  rest2  rest3  rest4  total
# date
# 2017-04-18    Tuesday        0           na   30.0   30.0   13.0   18.0   91.0
# 2017-04-19  Wednesday        0           na   20.0   11.0   30.0   18.0   79.0
# 2017-04-20   Thursday        0           na   22.0    3.0   19.0   46.0   90.0
# 2017-04-21     Friday        0           na   38.0   53.0   36.0   38.0  165.0
# 2017-04-22   Saturday        0           na   97.0   20.0   50.0   59.0  226.0

# %%
len(df1)
# Out:
# 478

# %%
478-30
# Out:
# 448

# %%
df1.columns
# Out:
# Index(['weekday', 'holiday', 'holiday_name', 'rest1', 'rest2', 'rest3',
#        'rest4', 'total'],
#       dtype='object')

# %%
cols=[ 'rest1', 'rest2', 'rest3','rest4', 'total']

# %%
for column in cols:
  df1[column]=df1[column].astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1.head()
# Out:
#              weekday  holiday    holiday_name  ...  rest3  rest4  total
# date                                           ...
# 2016-01-01    Friday        1  New Year's Day  ...     67    139    296
# 2016-01-02  Saturday        0              na  ...     43     85    191
# 2016-01-03    Sunday        0              na  ...     66     81    202
# 2016-01-04    Monday        0              na  ...     32     32    105
# 2016-01-05   Tuesday        0              na  ...     38     43     98
#
# [5 rows x 8 columns]

# %%
df1['total'].plot(figsize=(12,4))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
seasonal_decompose(df1['total']).plot();

# %%
ax=df1['total'].plot(figsize=(16,5))
for day in df1.query('holiday==1').index:
  ax.axvline(x=day,color='black',alpha=0.8);

# %%
len(df1)
# Out:
# 478

# %%
478-31
# Out:
# 447

# %%
train=df1.iloc[:436]
test=df1.iloc[436:]

# %%
pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 35.1 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 39.0 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
from pmdarima import auto_arima

# %%
auto_arima(df1['total'],seasonal=True,m=7,trace=True).summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8afb9717b126> in <module>()
# ----> 1 auto_arima(df1['total'],seasonal=True,m=7,trace=True).summary()
#
# NameError: name 'df1' is not defined

# %%
model=SARIMAX(train['total'],order=(0,0,0),seasonal_order=(1,0,1,7),enforce_invertibility=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
results=model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  SARIMAX Results
# ...
# Dep. Variable:                     total   No. Observations:                  436
# Model:             SARIMAX(1, 0, [1], 7)   Log Likelihood               -2165.369
# Date:                   Fri, 10 Sep 2021   AIC                           4336.738
# Time:                           21:25:10   BIC                           4348.970
# Sample:                       01-01-2016   HQIC                          4341.565
#                             - 03-11-2017
# Covariance Type:                     opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L7        0.9999   9.56e-05   1.05e+04      0.000       1.000       1.000
# ma.S.L7       -0.9384      0.024    -39.211      0.000      -0.985      -0.891
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
predicstions=results.predict(start,end).rename('SARIMA MODEL')

# %%
predictions.plot()

# %%
test['total'].plot(legend=True)
predicstions.plot(legend=True)

# %%
rmse(test['total'],predicstions)
# Out:
# 31.911759483007838

# %%
test['total'].mean()
# Out:
# 134.26190476190476

# %%
ax=test['total'].plot(legend=True)
predicstions.plot(legend=True)
for day in test.query('holiday==1').index:
  ax.axvline(x=day,color='black',alpha=0.8)

# %%
#from statsmodels.tools.eval_measures import rmse

# %%
#add exagenous variable 
auto_arima(df1['total'],exagenous=df1[['holiday']],seasonal=True,m=7,trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[7] intercept   : AIC=inf, Time=2.82 sec
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=5269.484, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=4916.749, Time=0.83 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=5049.644, Time=0.52 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=6126.084, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[7] intercept   : AIC=5200.790, Time=0.13 sec
#  ARIMA(1,0,0)(2,0,0)[7] intercept   : AIC=4845.442, Time=2.13 sec
#  ARIMA(1,0,0)(2,0,1)[7] intercept   : AIC=4921.866, Time=3.29 sec
#  ARIMA(1,0,0)(1,0,1)[7] intercept   : AIC=4788.853, Time=1.36 sec
#  ARIMA(1,0,0)(0,0,1)[7] intercept   : AIC=5058.642, Time=0.63 sec
#  ARIMA(1,0,0)(1,0,2)[7] intercept   : AIC=4951.692, Time=3.01 sec
#  ARIMA(1,0,0)(0,0,2)[7] intercept   : AIC=4982.776, Time=1.44 sec
#  ARIMA(1,0,0)(2,0,2)[7] intercept   : AIC=inf, Time=4.17 sec
#  ARIMA(0,0,0)(1,0,1)[7] intercept   : AIC=4775.690, Time=1.25 sec
# ...

# %%
#(0,0,0)(1,0,1,7
model=SARIMAX(train['total'],exog=train[['holiday']],order=(0,0,0),seasonal_order=(1,0,1,7),enforce_invertibility=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
results=model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  SARIMAX Results
# ...
# Dep. Variable:                     total   No. Observations:                  436
# Model:             SARIMAX(1, 0, [1], 7)   Log Likelihood               -2098.580
# Date:                   Fri, 10 Sep 2021   AIC                           4205.160
# Time:                           21:50:47   BIC                           4221.470
# Sample:                       01-01-2016   HQIC                          4211.596
#                             - 03-11-2017
# Covariance Type:                     opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# holiday       70.0750      3.972     17.640      0.000      62.289      77.861
# ar.S.L7        1.0000   4.72e-05   2.12e+04      0.000       1.000       1.000
# ...

# %%
start=len(train)
end=len(test)+len(train)-1

# %%
predictions=results.predict(start,end,exog=test[['holiday']]).rename('sarimax with exogenous')

# %%
ax=test['total'].plot(legend=True)
predictions.plot(legend=True)
for day in test.query('holiday==1').index:
  ax.axvline(x=day,color='black',alpha=0.8)

# %%
rmse(test['total'],predictions)
# Out:
# 22.811486942124947

# %%
test['total'].mean()
# Out:
# 134.26190476190476

# %%
#forecast into the Future 
model=SARIMAX(df1['total'],exog=df1[['holiday']],order=(0,0,0),seasonal_order=(1,0,1,7),enforce_invertibility=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
results=model.fit()

# %%
exog_forcast=df[478:][['holiday']]
exog_forcast
# Out:
#             holiday
# date
# 2017-04-23        0
# 2017-04-24        0
# 2017-04-25        0
# 2017-04-26        0
# 2017-04-27        0
# 2017-04-28        0
# 2017-04-29        0
# 2017-04-30        0
# 2017-05-01        0
# 2017-05-02        0
# 2017-05-03        0
# 2017-05-04        0
# 2017-05-05        1
# 2017-05-06        0
# 2017-05-07        0
# 2017-05-08        0
# 2017-05-09        0
# 2017-05-10        0
# 2017-05-11        0
# 2017-05-12        0
# 2017-05-13        0
# 2017-05-14        1
# 2017-05-15        0
# 2017-05-16        0
# 2017-05-17        0
# 2017-05-18        0
# 2017-05-19        0
# 2017-05-20        0
# 2017-05-21        0
# 2017-05-22        0
# 2017-05-23        0
# 2017-05-24        0
# 2017-05-25        0
# 2017-05-26        0
# 2017-05-27        0
# 2017-05-28        0
# 2017-05-29        1
# 2017-05-30        0
# 2017-05-31        0

# %%
fcast=results.predict(len(df1),len(df1)+38,exog=exog_forcast).rename('finale sarimax ')

# %%
df1['total'].plot(legend=True,figsize=(12,4))
fcast.plot(legend=True,figsize=(12,4))

# %%
ax=df1['total'].plot(legend=True)
predictions.plot(legend=True)
for day in df.query('holiday==1').index:
  ax.axvline(x=day,color='black',alpha=0.8)

# %%
#vector auto regression df`VAR
#in previous  SARIMAX EXAMPLE THE FORECAST variable y-t was influeneced by the exogenous predictor variable but not vice versa
#variables affect each others

# %%
import pandas as pd 
import numpy as np

# %%
#general steps involved in building VAR model are :
# examine the data 
#visualize the data 
# test for stationary 
#y1,t=c1+Q11,1Y1,t-1+Q12,1y2,t-1+e1,t
#y2,t=c2+Q21,1Y1,t-1+Q22,1y2,t-1+e2,t

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# %%
df=pd.read_csv("/content/drive/MyDrive/M2SLMoneyStock.csv",index_col=0,parse_dates=True)
df.index.freq='MS'
ps=pd.read_csv("/content/drive/MyDrive/PCEPersonalSpending.csv",index_col=0,parse_dates=True)
ps.index.frew='MS'

# %%
df.head()
# Out:
#              Money
# Date
# 1995-01-01  3492.4
# 1995-02-01  3489.9
# 1995-03-01  3491.1
# 1995-04-01  3499.2
# 1995-05-01  3524.2

# %%
ps.head()
# Out:
#             Spending
# Date
# 1995-01-01    4851.2
# 1995-02-01    4850.8
# 1995-03-01    4885.4
# 1995-04-01    4890.2
# 1995-05-01    4933.1

# %%
df=df.join(ps)

# %%
df=df.dropna()

# %%
df.plot(figsize=(12,4))

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(df['Money'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        4.239022
# p-value                   1.000000
# # lags used               4.000000
# # observations          247.000000
# critical value (1%)      -3.457105
# critical value (5%)      -2.873314
# critical value (10%)     -2.573044
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
adf_test(df['Spending'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic        0.149796
# p-value                   0.969301
# # lags used               3.000000
# # observations          248.000000
# critical value (1%)      -3.456996
# critical value (5%)      -2.873266
# critical value (10%)     -2.573019
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
df_transformed=df.diff()

# %%
adf_test(df_transformed['Money'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -2.057404
# p-value                   0.261984
# # lags used              15.000000
# # observations          235.000000
# critical value (1%)      -3.458487
# critical value (5%)      -2.873919
# critical value (10%)     -2.573367
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
adf_test(df_transformed['Spending'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -7.226974e+00
# p-value                 2.041027e-10
# # lags used             2.000000e+00
# # observations          2.480000e+02
# critical value (1%)    -3.456996e+00
# critical value (5%)    -2.873266e+00
# critical value (10%)   -2.573019e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed=df_transformed.diff().dropna()

# %%
adf_test(df_transformed['Money'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -7.077471e+00
# p-value                 4.760675e-10
# # lags used             1.400000e+01
# # observations          2.350000e+02
# critical value (1%)    -3.458487e+00
# critical value (5%)    -2.873919e+00
# critical value (10%)   -2.573367e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
df_transformed.head()
# Out:
#             Money  Spending
# Date
# 1995-03-01    3.7      35.0
# 1995-04-01    6.9     -29.8
# 1995-05-01   16.9      38.1
# 1995-06-01   -0.3       1.5
# 1995-07-01   -6.2     -51.7

# %%
#num observations 
nobs=12
train=df_transformed[:-nobs]
test=df_transformed[-nobs:]

# %%
#perform gridsearch for order p ar of VAR model

# %%
model=VAR(train)
for p in range(8):
  results=model.fit(p)
  print(f'Ordered {p}')
  print(f'AIC {results.aic}')
  print('\n')
# Out:
# Ordered 0
# AIC 14.74710921809045
#
#
# Ordered 1
# AIC 14.178610495220896
#
#
# Ordered 2
# AIC 13.955189367163705
#
#
# Ordered 3
# AIC 13.849518291541038
#
#
# Ordered 4
# AIC 13.827950574458281
#
#
# Ordered 5
# AIC 13.78730034460964
#
#
# Ordered 6
# AIC 13.799076756885809
#
#
# Ordered 7
# AIC 13.797638727913972

# %%
#lowest AIC value p=5
results=model.fit(5)

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 12, Sep, 2021
# Time:                     19:31:01
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    14.1131
# Nobs:                     233.000    HQIC:                   13.9187
# Log likelihood:          -2245.45    FPE:                    972321.
# AIC:                      13.7873    Det(Omega_mle):         886628.
# --------------------------------------------------------------------
# Results for equation Money
# ...
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.516683         1.782238            0.290           0.772
# L1.Money           -0.646232         0.068177           -9.479           0.000
# ...

# %%
#grab the 5 lagged values right before the test starts 
#numpy array
lagged_values=train.values[-5:]

# %%
z=results.forecast(y=lagged_values,steps=12)

# %%
idx=pd.date_range('2015-01-01',periods=12,freq='MS')

# %%
df_forecast=pd.DataFrame(z,index=idx,columns=['Mony_2d','spesnding_2d'])

# %%
df_forecast
# Out:
#               Mony_2d  spesnding_2d
# 2015-01-01 -16.995276     36.149820
# 2015-02-01  -3.174038    -11.450298
# 2015-03-01  -0.377725     -6.684969
# 2015-04-01  -2.602233      5.479458
# 2015-05-01   4.228557     -2.443365
# 2015-06-01   1.559393      0.387639
# 2015-07-01  -0.998410      3.883680
# 2015-08-01   0.364510     -2.356101
# 2015-09-01  -1.210627     -1.224147
# 2015-10-01   0.225877      0.786927
# 2015-11-01   1.338939      0.180974
# 2015-12-01  -0.218585      0.212750

# %%
#reverse the difference 
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['Mony_2d'] = (df['Money'].iloc[-nobs-1]-df['Money'].iloc[-nobs-2]) + df_forecast['Mony_2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['MoneyForecast'] = df['Money'].iloc[-nobs-1] + df_forecast['Mony_2d'].cumsum()

# %%
# Add the most recent first difference from the training side of the original dataset to the forecast cumulative sum
df_forecast['spesnding_2d'] = (df['Spending'].iloc[-nobs-1]-df['Spending'].iloc[-nobs-2]) + df_forecast['spesnding_2d'].cumsum()

# Now build the forecast values from the first difference set
df_forecast['SpendingForecast'] = df['Spending'].iloc[-nobs-1] + df_forecast['spesnding_2d'].cumsum()

# %%
test_range=df[-nobs:]

# %%
test_range.plot()

# %%
df_forecast[['MoneyForecast','SpendingForecast']].plot()

# %%
test_range['Money'].plot(legend=True)
df_forecast['MoneyForecast'].plot(legend=True)

# %%
test_range['Spending'].plot(legend=True)
df_forecast['SpendingForecast'].plot(legend=True)

# %%
rmse(test_range['Money'],df_forecast['MoneyForecast'])
# Out:
# 43.710496535589265

# %%
test_range['Money'].mean()
# Out:
# 12034.008333333333

# %%
rmse(test_range['Spending'],df_forecast['SpendingForecast'])
# Out:
# 37.00117516940808

# %%
test_range['Spending'].mean()
# Out:
# 12294.533333333333

# %%
############33DEEP LEARNING FOR TIME SERIES
